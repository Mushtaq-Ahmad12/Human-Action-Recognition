# %% [markdown]
# # Kaggle Training Pipeline: Human Action Recognition
# This notebook is fundamentally designed to instantly deploy your project to Kaggle to take advantage of their free **Tesla P100 or T4x2 GPUs** to heavily drastically accelerate the 30-frame BiLSTM temporal sequence calculations.

# %%
# 1. Pull the codebase directly from your GitHub repository
# !git clone https://github.com/Mushtaq-Ahmad12/Human-Action-Recognition.git
# %cd Human-Action-Recognition

# %%
# 2. Install all required dependencies
# !pip install -r requirements.txt

# %%
# 3. Fetch the Raw dataset videos directly into Kaggle output
# !python src/data/download.py

# %%
# 4. Preprocess the videos into deep temporal numpy sequences (30 Frames)
# !python src/data/preprocess.py

# %%
# 5. Execute Highly-Optimized BiLSTM Hardware GPU Training
# !python src/pipeline/train.py

# %%
# 6. Generate the Confusion Matrix and classification metrics
# !python src/pipeline/evaluate.py

# %%
# 7. Generate direct one-click download links to extract your trained weights off Kaggle for local inference!
from IPython.display import FileLink
display(FileLink(r'models/best_model.pth'))
display(FileLink(r'data/processed/training_history.png'))
display(FileLink(r'data/processed/confusion_matrix.png'))
